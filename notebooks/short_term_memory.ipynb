# %% [markdown]
# # Short-Term Memory

# %%
import dotenv
from agents import Agent, Runner, SQLiteSession, trace

dotenv.load_dotenv()
# Out:
# True

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
)

# %% [markdown]
# ## No Memory

# %%
result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")
print(result.final_output)
# Out:
# 1) Bananas: 8/10 - Rich in potassium, fiber, and vitamins; natural sugars but overall nutritious.
# 2) Lollipop: 2/10 - High in added sugars; little to no nutrients.

# %%
result = await Runner.run(nutrition_agent, "Add apples to the comparison")
print(result.final_output)
# Out:
# Please specify the other foods to compare apples with (e.g., bananas, grapes, almonds, cookies, etc.). If you want, I can compare apples against a few common options.

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", 
    session=session
)
print(result.final_output)
# Out:
# 1) Bananas: 7/10 - Whole food with fiber, potassium, and vitamins; contains natural sugar.
# 2) Lollipop: 2/10 - Mostly sugar; essentially no nutrients.

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", 
        session=session
    )

print(result.final_output)
# Out:
# 1) Apples: 8/10 - Rich in fiber, vitamin C, and polyphenols; low in calories per volume.
# 2) Bananas: 7/10 - Good fiber and potassium; natural sugars present.
# 3) Lollipop: 2/10 - Mostly sugar; negligible nutrients.
